# %%
class Student:  # 클래스는 대문자로 시작
    # 생성자 메서드
    def __init__(self, name, kor, eng):
        self.name = name
        self.kor = kor
        self.eng = eng
    # 메서드
    def total(self):
        return self.kor + self.eng

    def average(self):
        return self.total() / 2

    def print_info(self):
        print(f"이름 : {self.name}")
        print(f"국어 : {self.kor}")
        print(f"영어 : {self.eng}")
        print(f"총점 : {self.total()}")
        print(f"평균 : {self.average()}")

# %%
s1 = Student("홍길동", 100, 90)  #self는 Student 공간을 만드는 것임( new Student()같은 의미인거)
# Student.__init__(self, name, kor, eng) 호출하는 것임

print(s1.name)
print(s1.kor)
print(s1.eng)

s1.print_info()

s2= Student("김철수", 99, 95)
s2.print_info()
# Out:
# 홍길동
# 100
# 90
# 이름 : 홍길동
# 국어 : 100
# 영어 : 90
# 총점 : 190
# 평균 : 95.0
# 이름 : 김철수
# 국어 : 99
# 영어 : 95
# 총점 : 194
# 평균 : 97.0

# %%
class Account:

    def __init__(self, owner, balance):
        self.owner = owner
        self.balance = balance

    def deposit(self, money):
        self.balance += money

    def withdraw(self, money):
        self.balance -= money

    def print_info(self):
        print(f"예금주 : {self.owner}")
        print(f"잔액 : {self.balance:,}원")

# %%
acc = Account("홍길동", 10000)

acc.deposit(5000)
acc.withdraw(3000)

acc.print_info()
# Out:
# 예금주 : 홍길동
# 잔액 : 12,000원

# %%
class Car:

    def __init__(self, model):
        self.model = model
        self.speed = 0

    def accelerate(self):
        self.speed += 10

    def brake(self):
        self.speed -= 10

    def print_info(self):
        print(f"차량 : {self.model}")
        print(f"속도 : {self.speed:,}km/h")

# %%
car = Car("소나타")

car.accelerate()
car.accelerate()
car.brake()

car.print_info()
# Out:
# 차량 : 소나타
# 속도 : 10km/h

# %%
class TV:

    def __init__(self):
        self.power = False
        self.channel = 1

    def on(self):
        self.power = True

    def channel_up(self):
        self.channel += 1

    def print_info(self):
        print(f"전원 : {self.power}")
        print(f"채널 : {self.channel}")

# %%
tv = TV()

tv.on()
tv.channel_up()
tv.channel_up()

tv.print_info()
# Out:
# 전원 : True
# 채널 : 3

# %%
class Rectangle:

    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

    def perimeter(self):
        return (self.width + self.height) * 2

# %%
r = Rectangle(10, 5)

print(r.area())
print(r.perimeter())
# Out:
# 50
# 30
